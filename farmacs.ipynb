# %%
import pandas as pd
farmacs=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\23_antipsicotics_dispensats.csv")
# Out:
# C:\Users\laiar\AppData\Local\Temp\ipykernel_25148\175386664.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   farmacs=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\23_antipsicotics_dispensats.csv")

# %%
mhda=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\25_taula_farmacs_mhda_2010_2019_Final.csv")

# %%
farmacs["DES_HIS_Forma_Farmaceutica"].value_counts()
# Out:
# DES_HIS_Forma_Farmaceutica
# COMPRIMITS        6171269
# INJECTABLES EF    1408566
# SOLUCIONS          367358
# CÃPSULES          193151
# SUSPENSIONS           125
# Name: count, dtype: int64
