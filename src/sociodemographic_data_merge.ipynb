# %% [markdown]
# # Sociodemographic data Merging
# The table 1_taula_0_cohort_total_Final will be the base and then we're going to separate patients by 'Study' or 'Control' depending on if their idCas is located in '3_taula_0_cohort_estudi_Final' or '2_taula_0_cohort_control_Final'.

# %%
import pandas as pd
path_cohort = r"C:\Users\LRAJAG\Desktop\DATOS_PADRIS_nets\1_taula_0_cohort_total_Final.csv"

cols = pd.read_csv(path_cohort, sep=',', encoding='latin1', nrows=0).columns.tolist()
print(cols)
