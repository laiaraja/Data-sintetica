# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_total=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\1_taula_0_cohort_total_Final.csv")
df_study= pd.read_csv(r"C:\Users\laiar\Desktop\Classe IDIBAPS\data_sintetica\Data-sintetica\Data-sintetica\src\csv merged\cohort_estudi_sociodemografica.csv")
df_schizo= pd.read_csv(r"C:\Users\laiar\Desktop\Classe IDIBAPS\data_sintetica\Data-sintetica\Data-sintetica\src\csv merged\cohort_schizophrenia_sociodemografica.csv")
df_switchers= pd.read_csv(r"C:\Users\laiar\Desktop\Classe IDIBAPS\data_sintetica\Data-sintetica\Data-sintetica\src\csv merged\pdc_monthly_switchers.csv")
# Out:
# C:\Users\laiar\AppData\Local\Temp\ipykernel_2892\3637084362.py:1: DtypeWarning: Columns (9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_total=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\1_taula_0_cohort_total_Final.csv")

# %%
# Step 1: total mental health cohort
n_total = df_total.shape[0]
print(f"Total mental health cohort: {n_total}")
# Step 2: study cohort
n_study = df_study.shape[0]
print(f"Study cohort (age 18-64): {n_study}")
# Step 3: schizophrenia diagnosis
n_schiz = df_schizo.shape[0]
print(f"Schizophrenia diagnosis: {n_schiz}")
# Out:
# Total mental health cohort: 1421510
# Study cohort (age 18-64): 473812
# Schizophrenia diagnosis: 9635

# %%
df_23_dispensats=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\23_antipsicotics_dispensats.csv")
df_25_mhda=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\25_taula_farmacs_mhda_2010_2019_Final.csv")
# Out:
# C:\Users\laiar\AppData\Local\Temp\ipykernel_2892\4141433562.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_23_dispensats=pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\23_antipsicotics_dispensats.csv")

# %%
print(f"Total patients in cohort: {df_study['idCas'].nunique()}")
print(f"Patients with any dispensing in df23: {df_23_dispensats['idCas'].nunique()}")
print(f"Patients with any dispensing in df25: {df_25_mhda['idCas'].nunique()}")
print(f"Switchers: {patient_flags[patient_flags['switcher']].shape[0]}")

# %%
# Load table 11 (psychiatric diagnoses) and table 3 (study cohort)
df_t11 = pd.read_csv(r"C:\Users\laiar\Desktop\DATOS_PADRIS_nets\11_ap_dx_sm_cohort_Final.csv")

# Get study cohort IDs (age 18-64)
study_ids = set(df_study['idCas'])

# Filter table 11 to study cohort only
df_t11_study = df_t11[df_t11['idCas'].isin(study_ids)]

# Filter for schizophrenia: ICD-10 codes starting with F20
# The format seems to be "C01-F20.x" so we filter on the substring
df_schizo = df_t11_study[df_t11_study['PR_COD_PS'].str.contains('F20', na=False)]

# Count unique patients (a patient can have multiple F20 entries)
n_schizo_total = df_schizo['idCas'].nunique()
print(f"Schizophrenia patients in study cohort: {n_schizo_total}")

# Also useful to see the breakdown of F20 subtypes
print(df_schizo['PR_COD_PS'].value_counts().head(20))
# Out:
# Schizophrenia patients in study cohort: 9969
# PR_COD_PS
# C01-F20.9     6546
# C01-F20.0     4534
# C01-F20.5      255
# C01-F20.89      92
# C01-F20.3       64
# C01-F20.1       21
# C01-F20.2        9
# C01-F20.81       2
# Name: count, dtype: int64
