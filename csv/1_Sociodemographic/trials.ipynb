# %% [markdown]
# # Frequency checkups table 1

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\laiar\appdata\local\programs\python\python310\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\laiar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laiar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laiar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laiar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\laiar\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('MOCK_DATA_N_age_mod.csv')
df.head()
# Out:
#    id     sex    age  nationality smoking_status  healthcare_region  \
# 0   1  Female  35-64      Spanish      Ex-smoker  Central Catalonia
# 1   2    Male  15-19      Spanish     Non-smoker          Barcelona
# 2   3    Male  35-64      Spanish      Ex-smoker  Central Catalonia
# 3   4    Male  35-64      Spanish      Ex-smoker          Barcelona
# 4   5    Male    NaN  Non-spanish      Ex-smoker          Barcelona
#
#    comorbidities Socioeconomic_levels
# 0              2             Very Low
# 1              2                  Low
# 2              0                  Low
# 3              0             Very Low
# 4              1                  Low

# %% [markdown]
# ## Comorbidities

# %%
df.comorbidities.unique()
# Out:
# array([2, 0, 1])

# %%
df.comorbidities.value_counts(normalize=True)*100
# Out:
# comorbidities
# 0    52.4
# 2    25.1
# 1    22.5
# Name: proportion, dtype: float64

# %% [markdown]
# ## Healthcare regions

# %%
df.healthcare_region.value_counts(normalize=True)*100
# Out:
# healthcare_region
# Barcelona            66.5
# Girona                9.7
# Central Catalonia     8.0
# Tarragona             6.9
# Lleida                5.6
# Terres de l’Ebre      2.2
# Alt Pirineu           1.1
# Name: proportion, dtype: float64

# %%
# Aplicar el "buit" per deixar només el 98% de cobertura 
import numpy as np
num_buits = int(len(df) * 0.02)
indexs_buits = np.random.choice(df.index, size=num_buits, replace=False)
df.loc[indexs_buits, 'healthcare_region'] = np.nan

# %% [markdown]
# ## Age

# %%
df2=pd.read_csv('MOCK_DATA.csv')
df2.age.value_counts(normalize=True)*100
# Out:
# age
# 17    3.1
# 15    2.6
# 38    2.2
# 16    2.2
# 54    2.1
#      ...
# 14    0.2
# 70    0.2
# 75    0.2
# 97    0.1
# 83    0.1
# Name: proportion, Length: 100, dtype: float64

# %%
# 1. Definir els punts de tall (límits dels rangs)
# Els talls han de ser: 0-14, 15-19, 20-34, 35-64, i >65
# Posem 120 com a límit superior per a la gent gran
talls = [0, 14, 19, 34, 64, 120]
etiquetes = ['0-14', '15-19', '20-34', '35-64', '>65']

# 2. Agrupar les edats en aquests rangs temporalment
# Fem servir include_lowest=True perquè inclogui el 0
edat_per_rangs = pd.cut(df2['age'], bins=talls, labels=etiquetes, include_lowest=True)

# 3. Calcular i imprimir la freqüència
print("--- Freqüència per Rangs d'Edat ---")
counts = edat_per_rangs.value_counts(normalize=True).sort_index() * 100

print(counts.round(2).astype(str) + '%')
# Out:
# --- Freqüència per Rangs d'Edat ---
# age
# 0-14      9.5%
# 15-19    11.9%
# 20-34    16.1%
# 35-64    45.8%
# >65      16.7%
# Name: proportion, dtype: object

# %%
# 1. Carrego el fitxer on vull fer el canvi
df = pd.read_csv('MOCK_DATA_N_age_mod.csv')

# 2. Substituïm la columna 'age' per la de l'altre dataframe (df2)
# IMPORTANT: Assegura't que els dos fitxers tinguin el mateix nombre de files
df['age'] = df2['age']

# 3. Guardem el resultat sobreescrivint el fitxer o creant-ne un de nou
# Fem servir index=False per no afegir una columna extra de números a l'esquerra
df.to_csv('MOCK_DATA_N_age_mod.csv', index=False)
df.head()
# Out:
#    id     sex  age  nationality smoking_status  healthcare_region  \
# 0   1  Female   62      Spanish      Ex-smoker  Central Catalonia
# 1   2    Male   27      Spanish     Non-smoker          Barcelona
# 2   3    Male   36      Spanish      Ex-smoker  Central Catalonia
# 3   4    Male   42      Spanish      Ex-smoker          Barcelona
# 4   5    Male   52  Non-spanish      Ex-smoker          Barcelona
#
#    comorbidities Socioeconomic_levels
# 0              2             Very Low
# 1              2                  Low
# 2              0                  Low
# 3              0             Very Low
# 4              1                  Low

# %% [markdown]
# ## Smoking Status

# %%
df.smoking_status.value_counts(normalize=True)*100
# Out:
# smoking_status
# Smoker        37.0
# Ex-smoker     35.0
# Non-smoker    28.0
# Name: proportion, dtype: float64

# %%
# 1. Definir les probabilitats segons la taula 1 del document PADRIS-PRESTO
categories = ['Ever smoker', 'Never smoker']
weights = [0.4151, 0.5849] # 41.51% i 58.49%

# 2. Aplicar la distribució a la columna smoking_status
# Utilitzem len(df) per assegurar que omplim totes les files del teu fitxer
df['smoking_status'] = np.random.choice(categories, size=len(df), p=weights)

# 3. Aplicar cobertura del 54,3%
num_buits = int(len(df) * 0.457)
indexs_buits = np.random.choice(df.index, size=num_buits, replace=False)
df.loc[indexs_buits, 'smoking_status'] = np.nan

# 4. Guardar el fitxer amb els canvis
df.to_csv('MOCK_DATA_N_age_mod.csv', index=False)
print(df['smoking_status'].value_counts(normalize=True, dropna=False) * 100)
# Out:
# smoking_status
# NaN             45.7
# Never smoker    31.2
# Ever smoker     23.1
# Name: proportion, dtype: float64

# %%
import pandas as pd

# 1. Carregar el fitxer original des de la teva ruta
csv_path = 'C:/Users/LRAJAG/Desktop/Data_sintetica/csv/2_Comorbidities/COMORBIDITIES.csv' 
dfc = pd.read_csv(csv_path)

# 2. Substitució de la columna
# Assegura't que el 'df' que conté els smoking_status (Ever/Never/NaN) 
# s'ha generat amb el mateix nombre de files (N) que dfc.
dfc['smoking_status'] = df['smoking_status']

# 3. Guardar el fitxer
# Si vols sobreescriure el de l'escriptori, usa 'csv_path' en comptes de 'COMORBIDITIES.csv'
dfc.to_csv('COMORBIDITIES.csv', index=False)

# 4. Verificació final del que has creat
print("--- Validació segons PADRIS-PRESTO ---")
# Comprovem que els percentatges incloent els valors buits (NaN) siguin els correctes
print(dfc['smoking_status'].value_counts(dropna=False, normalize=True) * 100)

dfc.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 # 1. Carrego el fitxer on vull fer el canvi
#       2 path_comorb=''
# ----> 3 dfc = pd.read_csv('C:\\Users\\LRAJAG\\Desktop\\Data_sintetica\\csv\\2_Comorbidities\\COMORBIDITIES.csv', sep=',')
#       5 # 2. Substituïm la columna 'smoking_status' per la de l'altre dataframe (df)
#       6 # IMPORTANT: Assegura't que els dos fitxers tinguin el mateix nombre de files
#       7 dfc['smoking_status'] = df['smoking_status']
#
# File c:\Users\laiar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\laiar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\laiar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\laiar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\laiar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\LRAJAG\\Desktop\\Data_sintetica\\csv\\2_Comorbidities\\COMORBIDITIES.csv'
