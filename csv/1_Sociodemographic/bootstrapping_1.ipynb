# %%
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata

# %%
df = pd.read_csv('MOCK_DATA_N_age_mod.csv')

# %%
# 1. Preparar la informació del teu CSV
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df)

# 2. Entrenar la IA perquè aprengui com són els teus 1.000 pacients
synthesizer = CTGANSynthesizer(metadata)
synthesizer.fit(df)

# 3. Generar els 100.000 pacients nous (tots diferents!)
df_sintetic = synthesizer.sample(num_rows=100000)

# 4. Posar els IDs en ordre perquè no hi hagi salts
df_sintetic['ID_CAS'] = range(1, 100001)

df_sintetic.to_csv('csv\1_Sociodemographic\MOCK_DATA_100k.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:16: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:16: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\LRAJAG\AppData\Local\Temp\ipykernel_21064\2111739032.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv('csv\1_Sociodemographic\MOCK_DATA_N_age_mod.csv')
# C:\Users\LRAJAG\AppData\Local\Temp\ipykernel_21064\2111739032.py:16: SyntaxWarning: invalid escape sequence '\M'
#   df_sintetic.to_csv('csv\1_Sociodemographic\MOCK_DATA_100k.csv', index=False)
# C:\Users\LRAJAG\AppData\Local\Temp\ipykernel_21064\2111739032.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv('csv\1_Sociodemographic\MOCK_DATA_N_age_mod.csv')
# C:\Users\LRAJAG\AppData\Local\Temp\ipykernel_21064\2111739032.py:16: SyntaxWarning: invalid escape sequence '\M'
#   df_sintetic.to_csv('csv\1_Sociodemographic\MOCK_DATA_100k.csv', index=False)
# ...
